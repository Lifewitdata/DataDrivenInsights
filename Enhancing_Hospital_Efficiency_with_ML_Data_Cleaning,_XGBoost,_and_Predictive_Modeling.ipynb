# %% [markdown]
# <a href="https://colab.research.google.com/github/IsfaquethedataAnalyst/Dataanalysis/blob/main/Enhancing_Hospital_Efficiency_with_ML_Data_Cleaning%2C_XGBoost%2C_and_Predictive_Modeling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
train = pd.read_csv('train.csv')
train
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0           1              8                  c                   3
# 1           2              2                  c                   5
# 2           3             10                  e                   1
# 3           4             26                  b                   2
# 4           5             26                  b                   2
# ...       ...            ...                ...                 ...
# 4995     4996             19                  a                   7
# 4996     4997             26                  b                   2
# 4997     4998             32                  f                   9
# 4998     4999             26                  b                   2
# 4999     5000              9                  d                   5
#
#      Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
train.info()
train.Stay.unique()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 0 entries
# Data columns (total 18 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   case_id                            0 non-null      int64
#  1   Hospital_code                      0 non-null      int64
#  2   Hospital_type_code                 0 non-null      int64
#  3   City_Code_Hospital                 0 non-null      int64
#  4   Hospital_region_code               0 non-null      int64
#  5   Available Extra Rooms in Hospital  0 non-null      int64
#  6   Department                         0 non-null      int64
#  7   Ward_Type                          0 non-null      int64
#  8   Ward_Facility_Code                 0 non-null      int64
#  9   Bed Grade                          0 non-null      float64
#  10  patientid                          0 non-null      int64
#  11  City_Code_Patient                  0 non-null      float64
# ...

# %%
# NA values in train dataset
train.isnull().sum().sort_values(ascending = False)
# Out:
# case_id                              0.0
# Hospital_code                        0.0
# Admission_Deposit                    0.0
# Age                                  0.0
# Visitors with Patient                0.0
# Severity of Illness                  0.0
# Type of Admission                    0.0
# City_Code_Patient                    0.0
# patientid                            0.0
# Bed Grade                            0.0
# Ward_Facility_Code                   0.0
# Ward_Type                            0.0
# Department                           0.0
# Available Extra Rooms in Hospital    0.0
# Hospital_region_code                 0.0
# City_Code_Hospital                   0.0
# Hospital_type_code                   0.0
# Stay                                 0.0
# dtype: float64

# %%
test= pd.read_csv("test.csv")
test
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0      318439             21                  c                   3
# 1      318440             29                  a                   4
# 2      318441             26                  b                   2
# 3      318442              6                  a                   6
# 4      318443             28                  b                  11
# ...       ...            ...                ...                 ...
# 1995   320434             26                  b                   2
# 1996   320435             26                  b                   2
# 1997   320436             23                  a                   6
# 1998   320437             25                  e                   1
# 1999   320438             10                  e                   1
#
#      Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                       Z                                  3  gynecology
# ...

# %%
# NA values in test dataset
test.isnull().sum().sort_values(ascending = False)
# Out:
# case_id                              0.0
# Hospital_code                        0.0
# Admission_Deposit                    0.0
# Age                                  0.0
# Visitors with Patient                0.0
# Severity of Illness                  0.0
# Type of Admission                    0.0
# City_Code_Patient                    0.0
# patientid                            0.0
# Bed Grade                            0.0
# Ward_Facility_Code                   0.0
# Ward_Type                            0.0
# Department                           0.0
# Available Extra Rooms in Hospital    0.0
# Hospital_region_code                 0.0
# City_Code_Hospital                   0.0
# Hospital_type_code                   0.0
# Stay                                 0.0
# dtype: float64

# %%
# Number of distinct observations in train dataset
for i in train.columns:
    print(i, ':', train[i].nunique())
# Out:
# case_id : 0
# Hospital_code : 0
# Hospital_type_code : 0
# City_Code_Hospital : 0
# Hospital_region_code : 0
# Available Extra Rooms in Hospital : 0
# Department : 0
# Ward_Type : 0
# Ward_Facility_Code : 0
# Bed Grade : 0
# patientid : 0
# City_Code_Patient : 0
# Type of Admission : 0
# Severity of Illness : 0
# Visitors with Patient : 0
# Age : 0
# Admission_Deposit : 0
# Stay : 0

# %%
# Number of distinct observations in test dataset
for i in test.columns:
    print(i, ':', test[i].nunique())
# Out:
# case_id : 0
# Hospital_code : 0
# Hospital_type_code : 0
# City_Code_Hospital : 0
# Hospital_region_code : 0
# Available Extra Rooms in Hospital : 0
# Department : 0
# Ward_Type : 0
# Ward_Facility_Code : 0
# Bed Grade : 0
# patientid : 0
# City_Code_Patient : 0
# Type of Admission : 0
# Severity of Illness : 0
# Visitors with Patient : 0
# Age : 0
# Admission_Deposit : 0
# Stay : 0

# %%
# Replace missing values with the mode
train['Bed Grade'].fillna(train['Bed Grade'].mode()[0], inplace=True)
train['City_Code_Patient'].fillna(train['City_Code_Patient'].mode()[0], inplace=True)

# Print the DataFrame
print(train)
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0           1              8                  c                   3
# 1           2              2                  c                   5
# 2           3             10                  e                   1
# 3           4             26                  b                   2
# 4           5             26                  b                   2
# ...       ...            ...                ...                 ...
# 4995     4996             19                  a                   7
# 4996     4997             26                  b                   2
# 4997     4998             32                  f                   9
# 4998     4999             26                  b                   2
# 4999     5000              9                  d                   5
#
#      Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
# Replace missing values with the mode
test['Bed Grade'].fillna(test['Bed Grade'].mode()[0], inplace=True)
test['City_Code_Patient'].fillna(test['City_Code_Patient'].mode()[0], inplace=True)

# Print the DataFrame
print(test)
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0      318439             21                  c                   3
# 1      318440             29                  a                   4
# 2      318441             26                  b                   2
# 3      318442              6                  a                   6
# 4      318443             28                  b                  11
# ...       ...            ...                ...                 ...
# 1995   320434             26                  b                   2
# 1996   320435             26                  b                   2
# 1997   320436             23                  a                   6
# 1998   320437             25                  e                   1
# 1999   320438             10                  e                   1
#
#      Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                       Z                                  3  gynecology
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# Create an instance of LabelEncoder
le = LabelEncoder()

# Encode the 'Stay' column
train['Stay'] = le.fit_transform(train['Stay'].astype('str'))

# Print the encoded values
print(train['Stay'].unique())
# Out:
# [ 0  4  3  1  5  2  7 10  8  6  9]

# %%
# Set default value -1 for 'Stay' in 'test' DataFrame
train['Stay'] = -1

# Print the DataFrame
print(train)
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0           1              8                  c                   3
# 1           2              2                  c                   5
# 2           3             10                  e                   1
# 3           4             26                  b                   2
# 4           5             26                  b                   2
# ...       ...            ...                ...                 ...
# 4995     4996             19                  a                   7
# 4996     4997             26                  b                   2
# 4997     4998             32                  f                   9
# 4998     4999             26                  b                   2
# 4999     5000              9                  d                   5
#
#      Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
import pandas as pd
from sklearn.preprocessing import LabelEncoder

# Define the list of categorical columns
categorical_columns = ['Hospital_type_code', 'Hospital_region_code', 'Department', 'Ward_Type',
                       'Ward_Facility_Code', 'Type of Admission', 'Severity of Illness', 'Age']

# Iterate through each column
for col in categorical_columns:
    # Create a new LabelEncoder instance
    le = LabelEncoder()

    # Fit the LabelEncoder to the data in the current column
    le.fit(train[col])

    # Transform the data in the current column using the fitted LabelEncoder
    train[col] = le.transform(train[col])

# %%
# Filter data where Stay != -1
train = train[train['Stay'] != -1]

# Print the shape of the filtered DataFrame
print(train.shape)
# Out:
# (0, 18)

# %%
df = pd.read_csv("train.csv")

# %%
df
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0           1              8                  c                   3
# 1           2              2                  c                   5
# 2           3             10                  e                   1
# 3           4             26                  b                   2
# 4           5             26                  b                   2
# ...       ...            ...                ...                 ...
# 4995     4996             19                  a                   7
# 4996     4997             26                  b                   2
# 4997     4998             32                  f                   9
# 4998     4999             26                  b                   2
# 4999     5000              9                  d                   5
#
#      Hospital_region_code  Available Extra Rooms in Hospital    Department  \
# ...

# %%
# Filter the DataFrame based on the condition
train = df[df['Stay'] == -1]

# %%
df1 = pd.read_csv("test.csv")

# %%
df1
# Out:
#       case_id  Hospital_code Hospital_type_code  City_Code_Hospital  \
# 0      318439             21                  c                   3
# 1      318440             29                  a                   4
# 2      318441             26                  b                   2
# 3      318442              6                  a                   6
# 4      318443             28                  b                  11
# ...       ...            ...                ...                 ...
# 1995   320434             26                  b                   2
# 1996   320435             26                  b                   2
# 1997   320436             23                  a                   6
# 1998   320437             25                  e                   1
# 1999   320438             10                  e                   1
#
#      Hospital_region_code  Available Extra Rooms in Hospital  Department  \
# 0                       Z                                  3  gynecology
# ...

# %%
# Filter the DataFrame based on the condition
test = df1[df1['Stay'] == -1]

# %%
print(df1.shape)
# Out:
# (2000, 17)

# %%
# Specify the columns to be removed
columns_to_remove = ['Stay', 'patientid', 'Hospital_region_code', 'Ward_Facility_Code']

# Create a new DataFrame 'test1' by dropping the specified columns
test1 = test.drop(columns=columns_to_remove, axis=1)

# Now, 'test1' is a modified version of 'test' with the specified columns removed

# %%
print(test1.shape)
# Out:
# (0, 14)

# %%
# Specify the columns to be removed
columns_to_remove_train = ['case_id', 'patientid', 'Hospital_region_code', 'Ward_Facility_Code']

# Create a new DataFrame 'train1' by dropping the specified columns
train1 = train.drop(columns=columns_to_remove_train, axis=1)

# %%
print(train1.shape)
# Out:
# (0, 14)

# %%
# Label Encoding Stay column in train dataset
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
train['Stay'] = le.fit_transform(train['Stay'].astype('str'))

# %%
train.head()
# Out:
# Empty DataFrame
# Columns: [case_id, Hospital_code, Hospital_type_code, City_Code_Hospital, Hospital_region_code, Available Extra Rooms in Hospital, Department, Ward_Type, Ward_Facility_Code, Bed Grade, patientid, City_Code_Patient, Type of Admission, Severity of Illness, Visitors with Patient, Age, Admission_Deposit, Stay]
# Index: []

# %%
#Imputing dummy Stay column in test datset to concatenate with train dataset
test['Stay'] = -1
df = pd.concat([train, test])
df.shape
# Out:
# (0, 18)

# %%
#Label Encoding all the columns in Train and test datasets
for i in ['Hospital_type_code', 'Hospital_region_code', 'Department',
          'Ward_Type', 'Ward_Facility_Code', 'Type of Admission', 'Severity of Illness', 'Age']:
    le = LabelEncoder()
    df[i] = le.fit_transform(df[i].astype(str))

# %%
#Spearating Train and Test Datasets
train = df[df['Stay']!=-1]
test = df[df['Stay']==-1]

# %% [markdown]
# Feature **Engineering**

# %%
import numpy as np

def get_countid_enocde(train, test, cols, name):
  temp = train.groupby(cols)['case_id'].count().reset_index().rename(columns = {'case_id': name})
  temp2 = test.groupby(cols)['case_id'].count().reset_index().rename(columns = {'case_id': name})
  train = pd.merge(train, temp, how='left', on= cols)
  test = pd.merge(test,temp2, how='left', on= cols)
  train[name] = train[name].astype('float')
  test[name] = test[name].astype('float')
  train[name].fillna(np.median(temp[name]), inplace = True)
  test[name].fillna(np.median(temp2[name]), inplace = True)
  return train, test

# %%
train, test = get_countid_enocde(train, test, ['patientid'], name = 'count_id_patient')
train, test = get_countid_enocde(train, test,
                                 ['patientid', 'Hospital_region_code'], name = 'count_id_patient_hospitalCode')
train, test = get_countid_enocde(train, test,
                                 ['patientid', 'Ward_Facility_Code'], name = 'count_id_patient_wardfacilityCode')
# Out:
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# /usr/local/lib/python3.10/dist-packages/numpy/core/fromnumeric.py:3432: RuntimeWarning: Mean of empty slice.
#   return _methods._mean(a, axis=axis, dtype=dtype,
# /usr/local/lib/python3.10/dist-packages/numpy/core/_methods.py:190: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)

# %%
# Droping duplicate columns
test1 = test.drop(['Stay', 'patientid', 'Hospital_region_code', 'Ward_Facility_Code'], axis =1)
train1 = train.drop(['case_id', 'patientid', 'Hospital_region_code', 'Ward_Facility_Code'], axis =1)

# %%
# Assuming 'train1' is your DataFrame with columns modified as per the previous steps

# Create feature and target variables
X1 = train1.drop('Stay', axis=1)  # Feature variables (excluding 'Stay' column)
y1 = train1['Stay']  # Target variable

# Check if the dataset is large enough for the specified split
if len(X1) >= 2:
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=100)

    # Continue with the rest of your code for Naive Bayes and XGBoost

    # For Naive Bayes, you can use GaussianNB as an example
    from sklearn.naive_bayes import GaussianNB
    classifier_nb = GaussianNB()
    model_nb = classifier_nb.fit(X_train, y_train)
    prediction_nb = model_nb.predict(X_test)

    # Calculate the accuracy of the Naive Bayes model
    acc_score_nb = accuracy_score(y_test, prediction_nb)
    acc_score_nb = round(acc_score_nb, 2)
    print(f"Naive Bayes Model Accuracy: {acc_score_nb}")

    # For XGBoost, you can use the XGBoost code from the previous responses

else:
    print("Not enough samples in the dataset for the specified split.")
# Out:
# Not enough samples in the dataset for the specified split.

# %% [markdown]
# ***Models***
# Naive *Bayes* **Model**

# %%
# Assuming 'train1' is your DataFrame with columns modified as per the previous steps

# Create feature and target variables
X1 = train1.drop('Stay', axis=1)  # Feature variables (excluding 'Stay' column)
y1 = train1['Stay']  # Target variable

# Check if the dataset is large enough for the specified split
if len(X1) >= 2:
    # Split the data into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(X1, y1, test_size=0.2, random_state=100)

    # Naive Bayes
    from sklearn.naive_bayes import GaussianNB
    target_nb = y_train.values
    features_nb = X_train.values
    classifier_nb = GaussianNB()
    model_nb = classifier_nb.fit(features_nb, target_nb)
    prediction_nb = model_nb.predict(X_test)

    # Calculate the accuracy of the Naive Bayes model
    acc_score_nb = accuracy_score(prediction_nb, y_test)
    print("Naive Bayes Model Accuracy:", acc_score_nb * 100)

    # Continue with the rest of your code for XGBoost if needed

else:
    print("Not enough samples in the dataset for the specified split.")
# Out:
# Not enough samples in the dataset for the specified split.
